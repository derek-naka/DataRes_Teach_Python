# %% [markdown]
# # Natural Language Processing (NLP)

# %%
import pandas as pd

# import data
housing_data = pd.read_csv("zillow-data.csv")
housing_data.head(5)
# Out:
#             city              county state  property_type   price  \
# 0        Burbank  Los Angeles County    CA      TOWNHOUSE  685000
# 1         Sylmar  Los Angeles County    CA  SINGLE_FAMILY  688000
# 2    Los Angeles  Los Angeles County    CA      TOWNHOUSE  700000
# 3         Reseda  Los Angeles County    CA  SINGLE_FAMILY  700000
# 4  Panorama City  Los Angeles County    CA  SINGLE_FAMILY  690000
#
#                                          description
# 0  Cabrini Villas.Top of Hill.Private/Quiet/Grass...
# 1  SOLD BEFORE PROCESSING - Welcome home to this ...
# 2  This tri-level end unit is one of Just 55 unit...
# 3  3 Bedroom 2 bath home in the desirable area of...
# 4  Single family home first time back on the mark...

# %%
import textstat
from tqdm import tqdm, tqdm_pandas
tqdm.pandas()

housing_data["reading_ease"] = housing_data.description.progress_apply(lambda x: textstat.flesch_reading_ease(x))
housing_data["grade_level"] = housing_data.description.progress_apply(lambda x: textstat.text_standard(x, float_output = True))
housing_data["reading_time"] = housing_data.description.progress_apply(lambda x: textstat.reading_time(x, ms_per_char=14.69))
housing_data["sentence_count"] = housing_data.description.progress_apply(lambda x: textstat.sentence_count(x))
# Out:
# 100%|██████████| 300/300 [00:00<00:00, 1699.27it/s]
# 100%|██████████| 300/300 [00:00<00:00, 851.71it/s]
# 100%|██████████| 300/300 [00:00<00:00, 34200.13it/s]
# 100%|██████████| 300/300 [00:00<00:00, 17649.08it/s]

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
nltk.download('stopwords')
nltk.download('punkt')

def text_clean(string):
    words = []
    tokenizer = RegexpTokenizer((r'\w+')) # load function that tokenizes into words and keeps only alphanumeric characters 
    text = tokenizer.tokenize(string.lower()) # tokenize the input and lower every word
    text = nlp(" ".join(text)) 
    for token in text:
        # remove stopwords and lemmatize rest 
        if token.is_stop == False:
            words += [token.lemma_]
    return (" ").join(words)

housing_data["clean_description"] = housing_data.description.progress_apply(text_clean)
# Out:
# 100%|██████████| 300/300 [00:05<00:00, 51.73it/s]

# %%
import fasttext
from sklearn.decomposition import PCA

model = fasttext.train_unsupervised("cleaned_text_corpus.txt")

housing_data["vec"] = housing_data.clean_description.progress_apply(lambda x: model.get_sentence_vector(x))

pca = PCA(n_components=3)
housing_data['x'] = pca.fit_transform(housing_data["vec"].values.tolist())[:,0]
housing_data['y'] = pca.fit_transform(housing_data["vec"].values.tolist())[:,1]
housing_data['z'] = pca.fit_transform(housing_data["vec"].values.tolist())[:,2]
# Out:
# 100%|██████████| 300/300 [00:00<00:00, 1541.74it/s]

# %%
housing_data.head(5)
# Out:
#             city              county state  property_type   price  \
# 0        Burbank  Los Angeles County    CA      TOWNHOUSE  685000
# 1         Sylmar  Los Angeles County    CA  SINGLE_FAMILY  688000
# 2    Los Angeles  Los Angeles County    CA      TOWNHOUSE  700000
# 3         Reseda  Los Angeles County    CA  SINGLE_FAMILY  700000
# 4  Panorama City  Los Angeles County    CA  SINGLE_FAMILY  690000
#
#                                          description  reading_ease  \
# 0  Cabrini Villas.Top of Hill.Private/Quiet/Grass...         57.43
# 1  SOLD BEFORE PROCESSING - Welcome home to this ...         70.84
# 2  This tri-level end unit is one of Just 55 unit...         68.97
# 3  3 Bedroom 2 bath home in the desirable area of...         57.61
# 4  Single family home first time back on the mark...         71.85
#
#    grade_level  reading_time  sentence_count  \
# 0         12.0          7.84              15
# 1          8.0          4.61               4
# 2         11.0         10.86              13
# 3         11.0          3.22               2
# 4         11.0          4.91               4
#
#                                    clean_description  \
# 0  cabrini villas hill private quiet grassy gleno...
# 1  sell process welcome home lovely 3 bedroom 2 b...
# 2  tri level end unit 55 unit nestle new communit...
# 3  3 bedroom 2 bath home desirable area reseda co...
# 4  single family home time market 1975 great oppo...
#
#                                                  vec         x         y  \
# 0  [-0.02512608, 0.028402371, -0.12185228, -0.015... -0.005382 -0.042914
# 1  [-0.03434704, -0.009852296, -0.13140254, -0.01...  0.010132 -0.093050
# 2  [-0.036746506, 0.010594783, -0.13332342, -0.04... -0.128530 -0.052824
# 3  [-0.021491604, 0.013568662, -0.17267467, -0.03... -0.023203 -0.010952
# 4  [-0.02191974, -0.019852286, -0.13412026, -0.02...  0.076868  0.014223
#
#           z
# 0 -0.013894
# 1  0.053181
# 2 -0.047796
# 3  0.116257
# 4  0.085426
